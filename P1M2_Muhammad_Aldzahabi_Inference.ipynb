# %%
import joblib
import pandas as pd

# %%
Svm_model = joblib.load('SVM_Model.pkl')

# %%
df = pd.DataFrame({
    'CAR ID' : 1,
    'Brand' : 'Toyota',
    'Year' : 2001,
    'Engine Size' : 4.0,
    'Fuel Type' : 'Petrol',
    'Transmission' : 'Automatic',
    'Mileage' : 120000,
    'Condition' : 'Used',
    'Model' :'Camry'
}, index=[0])

predictions = Svm_model.predict(df)
print(f" Harga Mobil: {predictions[0]:.2f} USD")
# Out:
#  Harga Mobil: 53463.78 USD
